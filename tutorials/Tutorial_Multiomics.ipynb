# %% [markdown]
# # Fine-tuning on Pre-trained Model for Multiomic Integration
# In this tutorial, we demonstrate how to fine-tune a pre-trained model for multiomic integration. We use the BMMC dataset as an example for RNA and protein abundance data integration from CITE-seq. The BMMC dataset consists of multiple batches by donor origin. In the paired integration setting, each cell contains both RNA and protein measurements. We fine-tune on the pre-trained whole-body model.
#
# We summarize the fine-tuning pipeline in the following steps, which can be used as a general recipe for finetuning on integration tasks and beyond:
#
#      1. Specify hyper-parameter setup for integration task
#
#      2. Load and pre-process data
#
#      3. Load the pre-trained scGPT model
#
#      4. Finetune scGPT with task-specific objectives
#
#      5. Evaluate fine-tuned scGPT

# %%
import copy
import gc
import json
import os
os.environ["KMP_WARNINGS"] = "off"
from pathlib import Path
import sys
sys.path.insert(0, "../")
import time
import traceback
#from typing import List, Tuple, Dict, Union, Optional
import warnings
warnings.filterwarnings('ignore')

import torch
from anndata import AnnData
import scanpy as sc
import scvi
import numpy as np
import wandb
from scipy.sparse import issparse
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
import pandas as pd
import scipy.sparse as sp
from sklearn import preprocessing

from scgpt import prepare_data, prepare_dataloader, define_wandb_metrcis, evaluate, eval_testdata, train
from scgpt.tokenizer import tokenize_and_pad_batch
from scgpt.model import MultiOmicTransformerModel

import scgpt as scg
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.tokenizer import random_mask_value
from scgpt.loss import (
    masked_mse_loss,
    masked_relative_error,
    criterion_neg_log_bernoulli,
)
from scgpt.preprocess import Preprocessor
from scgpt.utils import set_seed, category_str2int, eval_scib_metrics

sc.set_figure_params(figsize=(4, 4))

# %% [markdown]
# ## Step1: Specify hyper-parameter setup for integration task
# Here we provide some hyper-parameter recommendations for the multiomic integration task. Note that the BMMC dataset contains multiple batches to be integrated. Therefore, in addition to the default gene modelling objectives, we also turn on DAR objectives specifically to faciliate batch integration. We also turn on the use_mod argument as default to ensure that the model is modality-aware during training.

# %%
hyperparameter_defaults = dict(
    task = 'multiomic',
    seed=42,
    dataset_name="BMMC", # Dataset name
    do_train=True, # Flag to indicate whether to do update model parameters during training
    load_model="./save/scGPT_human", # Path to pre-trained model
    freeze = False, #freeze
    GEP=True, # Gene expression modelling
    GEPC=True, # Gene expression modelling for cell objective
    CLS=False,
    ESC=False,
    DAR = True, # DAR objective weight for batch correction
    DSBN = False,  # Domain-spec batchnorm,
    mask_ratio=0.4, # Default mask ratio
    explicit_zero_prob = False,  # whether explicit bernoulli for zeros
    ecs_thres=0,  # Elastic cell similarity objective, 0.0 to 1.0, 0.0 to disable
    dab_weight=1.0,
    use_batch_labels = True,
    use_mod = True,
    per_seq_batch_sample = False,
    epochs=25, # Default number of epochs for fine-tuning
    input_layer_key = "X_binned", # Default expression value binning in data pre-processing
    n_bins=51, # Default number of bins for value binning in data pre-processing
    n_hvg = 1200,  # Default number of highly variable genes
    n_hvp = 4000,
    max_seq_len = 4001, # # Default n_hvg+1
    lr=1e-3, # Default learning rate for fine-tuning
    batch_size=16, # Default batch size for fine-tuning
    layer_size=512,
    nlayers=4,
    nhead=8, # if load model, batch_size, layer_size, nlayers, nhead will be ignored
    dropout=0.2, # Default dropout rate during model fine-tuning
    schedule_ratio=0.95,  # Default rate for learning rate decay
    save_eval_interval=5, # Default model evaluation interval
    log_interval=100, # Default log interval
    fast_transformer=True, # Default setting
    pre_norm=False, # Default setting
    amp=True,  # Default setting: Automatic Mixed Precision
    pad_token = "<pad>",
    mask_value = -1,
    pad_value = -2,
    include_zero_gene = False,
)

# %%
run = wandb.init(
    config=hyperparameter_defaults,
    project="scGPT",
    reinit='finish_previous',
    settings=wandb.Settings(start_method="fork"),
)
config = wandb.config
print(config)

set_seed(config.seed)
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/hys/scGPT/wandb/run-20250528_104518-xjgb760m</code>
# Syncing run <strong><a href='https://wandb.ai/apex_1465/scGPT/runs/xjgb760m' target="_blank">toasty-spaceship-11</a></strong> to <a href='https://wandb.ai/apex_1465/scGPT' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/apex_1465/scGPT' target="_blank">https://wandb.ai/apex_1465/scGPT</a>
#  View run at <a href='https://wandb.ai/apex_1465/scGPT/runs/xjgb760m' target="_blank">https://wandb.ai/apex_1465/scGPT/runs/xjgb760m</a>
# {'task': 'multiomic', 'seed': 42, 'dataset_name': 'BMMC', 'do_train': True, 'load_model': './save/scGPT_human', 'freeze': False, 'GEP': True, 'GEPC': True, 'CLS': False, 'ESC': False, 'DAR': True, 'DSBN': False, 'mask_ratio': 0.4, 'explicit_zero_prob': False, 'ecs_thres': 0, 'dab_weight': 1.0, 'use_batch_labels': True, 'use_mod': True, 'per_seq_batch_sample': False, 'epochs': 25, 'input_layer_key': 'X_binned', 'n_bins': 51, 'n_hvg': 1200, 'n_hvp': 4000, 'max_seq_len': 4001, 'lr': 0.001, 'batch_size': 16, 'layer_size': 512, 'nlayers': 4, 'nhead': 8, 'dropout': 0.2, 'schedule_ratio': 0.95, 'save_eval_interval': 5, 'log_interval': 100, 'fast_transformer': True, 'pre_norm': False, 'amp': True, 'pad_token': '<pad>', 'mask_value': -1, 'pad_value': -2, 'include_zero_gene': False}

# %%
# settings for input and preprocessing
special_tokens = [config.pad_token, "<cls>", "<eoc>"]

# %%
dataset_name = config.dataset_name
save_dir = Path(f"./save/dev_{dataset_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"save to {save_dir}")
logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# Out:
# save to save/dev_BMMC-May28-10-45

# %% [markdown]
# ## Step 2: Load and pre-process data

# %% [markdown]
# ### 2.1 Load the BMMC data
# Please download the data from https://drive.google.com/file/d/10RxboePS5p2Jj2Sfq1Ghzgqnl6nqPv5V/view?usp=sharing
#
# For the purpose of this tutorial, we selected a 12K+ cell subset from the BMMC dataset (originally 90K+ cells) to speed up training. More specifically, we filtered on the first 3 donors (batches) with B, Mono and T cell subtypes as shown in the data loading step below.

# %%
if dataset_name == 'BMMC':
    adata = sc.read('data/BMMC_processed.h5ad')
    # subset to first 3 donors with B, Mono and T cell subtypes
    adata = adata[adata.obs.DonorID.isin([10886, 11466, 12710]) & adata.obs.cell_type.isin(np.unique(adata.obs.cell_type.values)[:17])]
    adata.obs["celltype"] = adata.obs["cell_type"].astype(str).astype('category')
    adata.var["gene_name"] = adata.var.index.tolist()
    le = preprocessing.LabelEncoder()
    encoded_batch = le.fit_transform(adata.obs['batch'].values)
    adata.obs["batch_id"] =  encoded_batch
    adata.obs["str_batch"] = adata.obs["batch_id"].astype('category')
    adata_protein = adata[:, adata.var.feature_types.isin(['ADT'])].copy()
    adata_protein.var.index = ['p_' + i for i in adata_protein.var.index]
    adata = adata[:, adata.var.feature_types.isin(['GEX'])].copy()
    data_is_raw = False

# %%
if config.use_mod:
    gene_rna_df = pd.DataFrame(index = adata.var.index.tolist())
    gene_rna_df['mod'] = 'RNA'
    gene_protein_df = pd.DataFrame(index = adata_protein.var.index.tolist())
    gene_protein_df['mod'] = 'Protein'
    gene_loc_df = pd.concat([gene_rna_df, gene_protein_df])
    gene_loc_df['mod'] = gene_loc_df['mod'].astype('category')

# %% [markdown]
# ### 2.2 Cross-check gene set with the pre-trained model
# Note that we retain the common gene set between the data and the pre-trained model for further fine-tuning.

# %%
if config.load_model is not None:
    model_dir = Path(config.load_model)
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    old_vocab = vocab
embsize = config.layer_size
nhead = config.nhead
nlayers = config.nlayers
d_hid = config.layer_size
# Out:
# scGPT - INFO - match 12587/13953 genes in vocabulary of size 60697.

# %% [markdown]
# ### 2.3 Pre-process the data
# We follow the standardized pipline of depth normalization, log normalization, and highly vairable gene (HVG) selection for data pre-processing. We further introduce value binning to obtain the relative expressions of each HVG. Given multiple sequencing modalities, we perform the pre-processing steps on each individual modality first, and then combine them into multi-modal sequences as model input.

# %% [markdown]
# #### 2.3.1 Pre-process the RNA data

# %%
preprocessor = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=1,  # step 1
    filter_cell_by_counts=1,  # step 2
    normalize_total=1e4,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=data_is_raw,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=config.n_hvg,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor="seurat_v3" if data_is_raw else "cell_ranger",
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor(adata, batch_key=None)
# Out:
# scGPT - INFO - Filtering genes by counts ...
# scGPT - INFO - Filtering cells by counts ...
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Subsetting highly variable genes ...
# scGPT - WARNING - No batch_key is provided, will use all cells for HVG selection.
# scGPT - INFO - Binning data ...

# %% [markdown]
# #### 2.3.2 Pre-process the Protein data

# %%
preprocessor_protein = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=0,  # step 1
    filter_cell_by_counts=False,  # step 2
    normalize_total=False,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=False,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=False,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor=None,
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor_protein(adata_protein, batch_key=None)
# Out:
# scGPT - INFO - Binning data ...

# %% [markdown]
# #### 2.3.3 Combine RNA, and Protein data

# %%
data_combined = np.concatenate([adata.layers["X_binned"], adata_protein.layers["X_binned"]], axis=1)
adata = AnnData(
    X=data_combined,
    obs=adata.obs,
    var=pd.DataFrame(index=adata.var_names.tolist() + adata_protein.var_names.tolist()),
    layers={"X_binned": data_combined,}
)
adata.var["gene_name"] = adata.var.index.tolist()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12578 × 1334
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'celltype', 'batch_id', 'str_batch', 'n_counts'
#     var: 'gene_name'
#     layers: 'X_binned'

# %%
if config.per_seq_batch_sample:
    # sort the adata by batch_id in advance
    adata_sorted = adata[adata.obs["batch_id"].argsort()].copy()

# %% [markdown]
# ### 2.4 Tokenize the input data for model fine-tuning

# %%
all_counts = (
    adata.layers[config.input_layer_key].toarray()
    if issparse(adata.layers[config.input_layer_key])
    else adata.layers[config.input_layer_key]
)
genes = adata.var["gene_name"].tolist()

celltypes_labels = adata.obs["celltype"].tolist()  # make sure count from 0
num_types = len(set(celltypes_labels))
celltypes_labels = np.array(celltypes_labels)

batch_ids = adata.obs["batch_id"].tolist()
num_batch_types = len(set(batch_ids))
batch_ids = np.array(batch_ids)

# %%
if config.use_mod:
    mod_type = np.array([gene_loc_df.loc[g, 'mod'] for g in genes])
    vocab_mod = Vocab(VocabPybind(np.unique(gene_loc_df['mod']).tolist() + special_tokens, None))
    vocab_mod.set_default_index(vocab_mod["<pad>"])
    mod_type = np.array(vocab_mod(list(mod_type)), dtype=int)
    ntokens_mod = len(vocab_mod)

# %%
(
    train_data,
    valid_data,
    train_celltype_labels,
    valid_celltype_labels,
    train_batch_labels,
    valid_batch_labels,
) = train_test_split(
    all_counts, celltypes_labels, batch_ids, test_size=0.1, shuffle=True
)

# %%
num_of_non_zero_genes = [
    np.count_nonzero(train_data[i]) for i in range(train_data.shape[0])
]
print(f"max num of non_zero genes: {np.max(num_of_non_zero_genes)}")
print(f"min num of non_zero genes: {np.min(num_of_non_zero_genes)}")
print(f"average num of non_zero genes: {np.mean(num_of_non_zero_genes)}")
print(
    f"99% quantile num of non_zero genes: {np.quantile(num_of_non_zero_genes, 0.99)}"
)
print(f"max original values: {np.max(train_data)}")
print(
    f"average original non_zero values: {np.mean(train_data[np.nonzero(train_data)])}"
)
print(
    f"99% quantile original non_zero values: {np.quantile(train_data[np.nonzero(train_data)], 0.99)}"
)
print(f"num of celltypes: {num_types}")
# Out:
# max num of non_zero genes: 687
# min num of non_zero genes: 206
# average num of non_zero genes: 341.5295053003534
# 99% quantile num of non_zero genes: 510.0
# max original values: 50
# average original non_zero values: 25.3482856428962
# 99% quantile original non_zero values: 49.0
# num of celltypes: 17

# %%
if config.load_model is None:
    vocab = Vocab(VocabPybind(genes + special_tokens, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)
else:
    pretrained_genes = [g for g in genes + special_tokens if g in old_vocab]
    new_genes = [g for g in genes + special_tokens if g not in old_vocab]
    gene_ids_pretrained = np.array(old_vocab(pretrained_genes), dtype=int)
    # https://discuss.pytorch.org/t/expand-an-existing-embedding-and-linear-layer-nan-loss-value/55670/2
    # Retrieve pretrained weights
    vocab = Vocab(VocabPybind(pretrained_genes + new_genes, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)

# %%
tokenized_train = tokenize_and_pad_batch(
    train_data,
    gene_ids,
    max_len=config.max_seq_len,
    vocab=vocab,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    append_cls=True,  # append <cls> token at the beginning
    include_zero_gene=config.include_zero_gene,
    mod_type=mod_type if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)
tokenized_valid = tokenize_and_pad_batch(
    valid_data,
    gene_ids,
    max_len=config.max_seq_len,
    vocab=vocab,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    append_cls=True,
    include_zero_gene=config.include_zero_gene,
    mod_type=mod_type if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)
logger.info(
    f"train set number of samples: {tokenized_train['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_train['genes'].shape[1]}"
)
logger.info(
    f"valid set number of samples: {tokenized_valid['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_valid['genes'].shape[1]}"
)
# Out:
# scGPT - INFO - train set number of samples: 11320,
# 	 feature length: 688
# scGPT - INFO - valid set number of samples: 1258,
# 	 feature length: 663

# %% [markdown]
# ## Step 3: Load the pre-trained scGPT model
# Note that for multiomic integration, since the pre-trained model does not include the ATAC and protein tokens, we expand the embedding layer by adding these new tokens. We inherit only the gene embedding layer from the pre-trained model, and train rest of the model from scratch.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dict = torch.load(model_file)
ntokens = len(vocab)  # size of vocabulary
model = MultiOmicTransformerModel(
    ntokens,
    embsize,
    nhead,
    d_hid, 
    nlayers,
    vocab=vocab,
    dropout=config.dropout,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    do_mvc=config.GEPC,
    do_dab=config.DAR,
    use_batch_labels=config.use_batch_labels,
    num_batch_labels=num_batch_types,
    domain_spec_batchnorm=config.DSBN,
    n_input_bins=config.n_bins,
    ecs_threshold=config.ecs_thres,
    explicit_zero_prob=config.explicit_zero_prob,
    use_fast_transformer=config.fast_transformer,
    pre_norm=config.pre_norm,
    use_mod=config.use_mod,
    ntokens_mod=ntokens_mod if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)

with torch.no_grad():
    pretrained_emb_weights = model_dict['encoder.embedding.weight'][gene_ids_pretrained, :]
    model.encoder.embedding.weight.data[:len(pretrained_genes), :] = pretrained_emb_weights
    model.encoder.enc_norm.weight.data = model_dict['encoder.enc_norm.weight']
ntokens = len(vocab)

model.to(device)
wandb.watch(model)
print(model)
# Out:
# MultiOmicTransformerModel(
#   (encoder): GeneEncoder(
#     (embedding): Embedding(1337, 512, padding_idx=1089)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (value_encoder): ContinuousValueEncoder(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (linear1): Linear(in_features=1, out_features=512, bias=True)
#     (activation): ReLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (batch_encoder): BatchLabelEncoder(
#     (embedding): Embedding(3, 512)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (mod_encoder): BatchLabelEncoder(
#     (embedding): Embedding(5, 512, padding_idx=2)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (1): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (2): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (3): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (decoder): ExprDecoder(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
#   (cls_decoder): ClsDecoder(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): ReLU()
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (mvc_decoder): MVCDecoder(
#     (gene2query): Linear(in_features=1024, out_features=1024, bias=True)
#     (query_activation): Sigmoid()
#     (W): Linear(in_features=1024, out_features=1024, bias=False)
#   )
#   (grad_reverse_discriminator): AdversarialDiscriminator(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=3, bias=True)
#   )
#   (sim): Similarity(
#     (cos): CosineSimilarity()
#   )
#   (creterion_cce): CrossEntropyLoss()
# )

# %%
if config.GEP and config.GEPC:
    criterion_gep_gepc = masked_mse_loss
if config.CLS:
    criterion_cls = nn.CrossEntropyLoss()
if config.DAR:
    criterion_dab = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=config.lr, eps=1e-4 if config.amp else 1e-8
)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=config.schedule_ratio)
scaler = torch.cuda.amp.GradScaler(enabled=config.amp)

# %% [markdown]
# ## Step 4: Finetune scGPT with task-specific objectives

# %%
best_val_loss = float("inf")
best_avg_bio = 0.0
best_model = None
define_wandb_metrcis()

for epoch in range(1, config.epochs + 1):
    epoch_start_time = time.time()
    train_data_pt, valid_data_pt = prepare_data(
        tokenized_train=tokenized_train, 
        tokenized_valid=tokenized_valid, 
        train_batch_labels=train_batch_labels,
        valid_batch_labels=valid_batch_labels,
        config=config,
        epoch=epoch,
        sort_seq_batch=config.per_seq_batch_sample)
    
    train_loader = prepare_dataloader(
        train_data_pt,
        batch_size=config.batch_size,
        shuffle=True,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config.per_seq_batch_sample
    )
    valid_loader = prepare_dataloader(
        valid_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config.per_seq_batch_sample
    )

    if config.do_train:
        train(
            model=model,
            loader=train_loader,
            vocab=vocab,
            criterion_gep_gepc=criterion_gep_gepc if config.GEP and config.GEPC else None,
            criterion_dab=criterion_dab if config.DAR else None,
            criterion_cls=criterion_cls if config.CLS else None,
            scaler=scaler,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            config=config,
            logger=logger,
            epoch=epoch,
        )
    val_loss = evaluate(
        model=model,
        loader=valid_loader,
        vocab=vocab,
        criterion_gep_gepc=criterion_gep_gepc if config.GEP and config.GEPC else None,
        criterion_dab=criterion_dab if config.DAR else None,
        criterion_cls=criterion_cls if config.CLS else None,
        device=device,
        config=config,
        epoch=epoch
    )
    elapsed = time.time() - epoch_start_time
    logger.info("-" * 89)
    logger.info(
        f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | "
        f"valid loss {val_loss:5.4f} | "
    )
    logger.info("-" * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        best_model_epoch = epoch
        logger.info(f"Best model with score {best_val_loss:5.4f}")

    if epoch % config.save_eval_interval == 0 or epoch == config.epochs:
        logger.info(f"Saving model to {save_dir}")
        torch.save(best_model.state_dict(), save_dir / f"model_e{best_model_epoch}.pt")

        # eval on testdata
        results = eval_testdata(
            model = best_model,
            adata_t = adata_sorted if config.per_seq_batch_sample else adata,
            gene_ids = gene_ids,
            vocab = vocab,
            config = config,
            logger = logger,
            include_types=["cls"],
        )
        results["batch_umap"].savefig(
            save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png", dpi=300
        )

        results["celltype_umap"].savefig(
            save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png", dpi=300
        )
        metrics_to_log = {"test/" + k: v for k, v in results.items()}
        metrics_to_log["test/batch_umap"] = wandb.Image(
            str(save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )

        metrics_to_log["test/celltype_umap"] = wandb.Image(
            str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )
        metrics_to_log["test/best_model_epoch"] = best_model_epoch
        wandb.log(metrics_to_log)
        wandb.log({"avg_bio": results.get("avg_bio", 0.0)})

    scheduler.step()
# Out:
# random masking at epoch   1, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   1 | 100/708 batches | lr 0.00100 | ms/batch 26.51 | loss 9048.12 | gep 376.05 |gepc 8670.88 |dar  1.18 |
# scGPT - INFO - | epoch   1 | 200/708 batches | lr 0.00100 | ms/batch 27.87 | loss 280.73 | gep 202.51 |gepc 77.24 |dar  0.97 |
# scGPT - INFO - | epoch   1 | 300/708 batches | lr 0.00100 | ms/batch 21.25 | loss 280.61 | gep 202.68 |gepc 76.93 |dar  0.99 |
# scGPT - INFO - | epoch   1 | 400/708 batches | lr 0.00100 | ms/batch 27.53 | loss 165.25 | gep 89.81 |gepc 74.45 |dar  0.98 |
# scGPT - INFO - | epoch   1 | 500/708 batches | lr 0.00100 | ms/batch 27.29 | loss 129.85 | gep 65.99 |gepc 63.05 |dar  0.81 |
# scGPT - INFO - | epoch   1 | 600/708 batches | lr 0.00100 | ms/batch 31.54 | loss 129.60 | gep 65.42 |gepc 63.39 |dar  0.79 |
# scGPT - INFO - | epoch   1 | 700/708 batches | lr 0.00100 | ms/batch 26.69 | loss 122.98 | gep 62.27 |gepc 59.92 |dar  0.79 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   1 | time: 19.91s | valid loss 64.6910 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 64.6910
# random masking at epoch   2, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   2 | 100/708 batches | lr 0.00095 | ms/batch 27.03 | loss 123.93 | gep 61.88 |gepc 61.27 |dar  0.78 |
# scGPT - INFO - | epoch   2 | 200/708 batches | lr 0.00095 | ms/batch 29.16 | loss 121.36 | gep 60.22 |gepc 60.42 |dar  0.73 |
# scGPT - INFO - | epoch   2 | 300/708 batches | lr 0.00095 | ms/batch 30.60 | loss 119.88 | gep 59.34 |gepc 59.84 |dar  0.69 |
# scGPT - INFO - | epoch   2 | 400/708 batches | lr 0.00095 | ms/batch 32.61 | loss 117.77 | gep 58.15 |gepc 58.90 |dar  0.72 |
# scGPT - INFO - | epoch   2 | 500/708 batches | lr 0.00095 | ms/batch 26.67 | loss 117.15 | gep 57.72 |gepc 58.67 |dar  0.76 |
# scGPT - INFO - | epoch   2 | 600/708 batches | lr 0.00095 | ms/batch 26.35 | loss 113.97 | gep 56.10 |gepc 57.15 |dar  0.72 |
# scGPT - INFO - | epoch   2 | 700/708 batches | lr 0.00095 | ms/batch 18.91 | loss 115.20 | gep 56.96 |gepc 57.50 |dar  0.74 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   2 | time: 20.02s | valid loss 57.2889 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 57.2889
# random masking at epoch   3, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   3 | 100/708 batches | lr 0.00090 | ms/batch 26.83 | loss 114.98 | gep 56.46 |gepc 57.80 |dar  0.71 |
# scGPT - INFO - | epoch   3 | 200/708 batches | lr 0.00090 | ms/batch 31.38 | loss 111.31 | gep 54.78 |gepc 55.81 |dar  0.73 |
# scGPT - INFO - | epoch   3 | 300/708 batches | lr 0.00090 | ms/batch 27.33 | loss 111.95 | gep 55.11 |gepc 56.16 |dar  0.67 |
# scGPT - INFO - | epoch   3 | 400/708 batches | lr 0.00090 | ms/batch 28.11 | loss 110.76 | gep 54.45 |gepc 55.63 |dar  0.69 |
# scGPT - INFO - | epoch   3 | 500/708 batches | lr 0.00090 | ms/batch 26.77 | loss 111.48 | gep 55.06 |gepc 55.76 |dar  0.65 |
# scGPT - INFO - | epoch   3 | 600/708 batches | lr 0.00090 | ms/batch 30.27 | loss 111.29 | gep 54.55 |gepc 56.00 |dar  0.74 |
# scGPT - INFO - | epoch   3 | 700/708 batches | lr 0.00090 | ms/batch 27.16 | loss 111.55 | gep 54.75 |gepc 56.08 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   3 | time: 20.95s | valid loss 54.1599 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 54.1599
# random masking at epoch   4, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   4 | 100/708 batches | lr 0.00086 | ms/batch 28.45 | loss 109.11 | gep 53.63 |gepc 54.80 |dar  0.68 |
# scGPT - INFO - | epoch   4 | 200/708 batches | lr 0.00086 | ms/batch 27.34 | loss 109.08 | gep 53.57 |gepc 54.81 |dar  0.70 |
# scGPT - INFO - | epoch   4 | 300/708 batches | lr 0.00086 | ms/batch 28.23 | loss 108.62 | gep 53.45 |gepc 54.46 |dar  0.71 |
# scGPT - INFO - | epoch   4 | 400/708 batches | lr 0.00086 | ms/batch 20.23 | loss 107.09 | gep 52.65 |gepc 53.79 |dar  0.65 |
# scGPT - INFO - | epoch   4 | 500/708 batches | lr 0.00086 | ms/batch 26.68 | loss 108.86 | gep 53.41 |gepc 54.72 |dar  0.73 |
# scGPT - INFO - | epoch   4 | 600/708 batches | lr 0.00086 | ms/batch 30.62 | loss 109.93 | gep 53.88 |gepc 55.31 |dar  0.74 |
# scGPT - INFO - | epoch   4 | 700/708 batches | lr 0.00086 | ms/batch 27.01 | loss 108.51 | gep 53.28 |gepc 54.51 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   4 | time: 19.56s | valid loss 53.1770 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 53.1770
# random masking at epoch   5, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   5 | 100/708 batches | lr 0.00081 | ms/batch 27.46 | loss 109.56 | gep 53.81 |gepc 55.03 |dar  0.73 |
# scGPT - INFO - | epoch   5 | 200/708 batches | lr 0.00081 | ms/batch 27.50 | loss 105.95 | gep 51.91 |gepc 53.32 |dar  0.72 |
# scGPT - INFO - | epoch   5 | 300/708 batches | lr 0.00081 | ms/batch 26.78 | loss 108.03 | gep 52.99 |gepc 54.36 |dar  0.67 |
# scGPT - INFO - | epoch   5 | 400/708 batches | lr 0.00081 | ms/batch 31.84 | loss 106.16 | gep 52.10 |gepc 53.35 |dar  0.70 |
# scGPT - INFO - | epoch   5 | 500/708 batches | lr 0.00081 | ms/batch 26.32 | loss 106.21 | gep 52.11 |gepc 53.40 |dar  0.70 |
# scGPT - INFO - | epoch   5 | 600/708 batches | lr 0.00081 | ms/batch 28.07 | loss 105.89 | gep 52.07 |gepc 53.17 |dar  0.65 |
# scGPT - INFO - | epoch   5 | 700/708 batches | lr 0.00081 | ms/batch 29.09 | loss 107.10 | gep 52.73 |gepc 53.67 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   5 | time: 20.48s | valid loss 51.7207 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.7207
# scGPT - INFO - Saving model to save/dev_BMMC-May28-10-45
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:03<00:00, 197.76it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.701917
# ARI_cluster/label          0.745601
# ASW_label                  0.672867
# ASW_label/batch            0.811369
# PCR_batch                  0.277857
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.860004
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6729, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.2779, ASW (batch): 0.8114, graph connectivity: 0.8600, graph iLISI: nan
# random masking at epoch   6, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   6 | 100/708 batches | lr 0.00077 | ms/batch 23.40 | loss 107.31 | gep 52.83 |gepc 53.79 |dar  0.69 |
# scGPT - INFO - | epoch   6 | 200/708 batches | lr 0.00077 | ms/batch 26.17 | loss 105.36 | gep 51.76 |gepc 52.86 |dar  0.74 |
# scGPT - INFO - | epoch   6 | 300/708 batches | lr 0.00077 | ms/batch 27.88 | loss 105.67 | gep 51.80 |gepc 53.16 |dar  0.72 |
# scGPT - INFO - | epoch   6 | 400/708 batches | lr 0.00077 | ms/batch 28.34 | loss 105.83 | gep 52.00 |gepc 53.15 |dar  0.69 |
# scGPT - INFO - | epoch   6 | 500/708 batches | lr 0.00077 | ms/batch 28.65 | loss 104.73 | gep 51.39 |gepc 52.66 |dar  0.69 |
# scGPT - INFO - | epoch   6 | 600/708 batches | lr 0.00077 | ms/batch 28.25 | loss 105.18 | gep 51.77 |gepc 52.75 |dar  0.66 |
# scGPT - INFO - | epoch   6 | 700/708 batches | lr 0.00077 | ms/batch 31.69 | loss 103.66 | gep 50.96 |gepc 52.04 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   6 | time: 20.20s | valid loss 52.6452 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   7, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   7 | 100/708 batches | lr 0.00074 | ms/batch 28.19 | loss 106.03 | gep 51.84 |gepc 53.47 |dar  0.72 |
# scGPT - INFO - | epoch   7 | 200/708 batches | lr 0.00074 | ms/batch 26.01 | loss 103.14 | gep 50.62 |gepc 51.85 |dar  0.67 |
# scGPT - INFO - | epoch   7 | 300/708 batches | lr 0.00074 | ms/batch 28.19 | loss 105.61 | gep 51.89 |gepc 53.03 |dar  0.70 |
# scGPT - INFO - | epoch   7 | 400/708 batches | lr 0.00074 | ms/batch 27.08 | loss 103.15 | gep 50.72 |gepc 51.73 |dar  0.71 |
# scGPT - INFO - | epoch   7 | 500/708 batches | lr 0.00074 | ms/batch 24.22 | loss 104.84 | gep 51.73 |gepc 52.42 |dar  0.69 |
# scGPT - INFO - | epoch   7 | 600/708 batches | lr 0.00074 | ms/batch 28.19 | loss 104.22 | gep 51.21 |gepc 52.31 |dar  0.70 |
# scGPT - INFO - | epoch   7 | 700/708 batches | lr 0.00074 | ms/batch 29.31 | loss 105.10 | gep 51.64 |gepc 52.75 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   7 | time: 19.87s | valid loss 52.6149 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   8, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   8 | 100/708 batches | lr 0.00070 | ms/batch 29.86 | loss 105.76 | gep 52.06 |gepc 53.01 |dar  0.69 |
# scGPT - INFO - | epoch   8 | 200/708 batches | lr 0.00070 | ms/batch 28.64 | loss 103.79 | gep 51.00 |gepc 52.07 |dar  0.72 |
# scGPT - INFO - | epoch   8 | 300/708 batches | lr 0.00070 | ms/batch 30.81 | loss 103.19 | gep 50.69 |gepc 51.80 |dar  0.71 |
# scGPT - INFO - | epoch   8 | 400/708 batches | lr 0.00070 | ms/batch 26.82 | loss 103.28 | gep 50.68 |gepc 51.91 |dar  0.69 |
# scGPT - INFO - | epoch   8 | 500/708 batches | lr 0.00070 | ms/batch 25.31 | loss 103.54 | gep 51.02 |gepc 51.84 |dar  0.68 |
# scGPT - INFO - | epoch   8 | 600/708 batches | lr 0.00070 | ms/batch 29.22 | loss 104.84 | gep 51.59 |gepc 52.54 |dar  0.71 |
# scGPT - INFO - | epoch   8 | 700/708 batches | lr 0.00070 | ms/batch 26.96 | loss 101.60 | gep 49.90 |gepc 50.98 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   8 | time: 20.54s | valid loss 55.0859 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   9, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   9 | 100/708 batches | lr 0.00066 | ms/batch 32.35 | loss 102.43 | gep 50.36 |gepc 51.33 |dar  0.75 |
# scGPT - INFO - | epoch   9 | 200/708 batches | lr 0.00066 | ms/batch 20.58 | loss 102.00 | gep 50.09 |gepc 51.19 |dar  0.73 |
# scGPT - INFO - | epoch   9 | 300/708 batches | lr 0.00066 | ms/batch 28.72 | loss 102.06 | gep 50.07 |gepc 51.29 |dar  0.71 |
# scGPT - INFO - | epoch   9 | 400/708 batches | lr 0.00066 | ms/batch 26.28 | loss 103.39 | gep 50.83 |gepc 51.87 |dar  0.69 |
# scGPT - INFO - | epoch   9 | 500/708 batches | lr 0.00066 | ms/batch 26.11 | loss 103.48 | gep 50.82 |gepc 51.97 |dar  0.69 |
# scGPT - INFO - | epoch   9 | 600/708 batches | lr 0.00066 | ms/batch 30.86 | loss 102.77 | gep 50.56 |gepc 51.56 |dar  0.65 |
# scGPT - INFO - | epoch   9 | 700/708 batches | lr 0.00066 | ms/batch 27.03 | loss 102.55 | gep 50.31 |gepc 51.54 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   9 | time: 20.04s | valid loss 51.0037 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.0037
# random masking at epoch  10, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  10 | 100/708 batches | lr 0.00063 | ms/batch 29.26 | loss 103.95 | gep 51.07 |gepc 52.15 |dar  0.73 |
# scGPT - INFO - | epoch  10 | 200/708 batches | lr 0.00063 | ms/batch 26.15 | loss 102.17 | gep 50.17 |gepc 51.28 |dar  0.72 |
# scGPT - INFO - | epoch  10 | 300/708 batches | lr 0.00063 | ms/batch 26.90 | loss 100.69 | gep 49.39 |gepc 50.61 |dar  0.69 |
# scGPT - INFO - | epoch  10 | 400/708 batches | lr 0.00063 | ms/batch 27.41 | loss 101.89 | gep 50.24 |gepc 50.93 |dar  0.72 |
# scGPT - INFO - | epoch  10 | 500/708 batches | lr 0.00063 | ms/batch 30.28 | loss 103.34 | gep 50.84 |gepc 51.81 |dar  0.70 |
# scGPT - INFO - | epoch  10 | 600/708 batches | lr 0.00063 | ms/batch 19.48 | loss 102.04 | gep 50.31 |gepc 51.07 |dar  0.67 |
# scGPT - INFO - | epoch  10 | 700/708 batches | lr 0.00063 | ms/batch 28.03 | loss 101.94 | gep 50.17 |gepc 51.05 |dar  0.73 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  10 | time: 19.53s | valid loss 51.2694 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-May28-10-45
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:05<00:00, 156.02it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.788697
# ARI_cluster/label          0.941292
# ASW_label                  0.644385
# ASW_label/batch            0.827708
# PCR_batch                  0.392434
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.906676
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6444, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3924, ASW (batch): 0.8277, graph connectivity: 0.9067, graph iLISI: nan
# random masking at epoch  11, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  11 | 100/708 batches | lr 0.00060 | ms/batch 27.21 | loss 102.95 | gep 50.51 |gepc 51.76 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 200/708 batches | lr 0.00060 | ms/batch 27.77 | loss 101.25 | gep 49.80 |gepc 50.75 |dar  0.70 |
# scGPT - INFO - | epoch  11 | 300/708 batches | lr 0.00060 | ms/batch 28.51 | loss 101.00 | gep 49.58 |gepc 50.72 |dar  0.70 |
# scGPT - INFO - | epoch  11 | 400/708 batches | lr 0.00060 | ms/batch 26.63 | loss 100.96 | gep 49.67 |gepc 50.58 |dar  0.71 |
# scGPT - INFO - | epoch  11 | 500/708 batches | lr 0.00060 | ms/batch 25.90 | loss 102.41 | gep 50.41 |gepc 51.30 |dar  0.70 |
# scGPT - INFO - | epoch  11 | 600/708 batches | lr 0.00060 | ms/batch 33.03 | loss 102.23 | gep 50.32 |gepc 51.22 |dar  0.69 |
# scGPT - INFO - | epoch  11 | 700/708 batches | lr 0.00060 | ms/batch 25.30 | loss 101.71 | gep 49.97 |gepc 51.00 |dar  0.74 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  11 | time: 20.31s | valid loss 52.0424 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  12, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  12 | 100/708 batches | lr 0.00057 | ms/batch 25.35 | loss 102.22 | gep 50.31 |gepc 51.23 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 200/708 batches | lr 0.00057 | ms/batch 17.38 | loss 100.44 | gep 49.41 |gepc 50.35 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 300/708 batches | lr 0.00057 | ms/batch 26.79 | loss 100.13 | gep 49.30 |gepc 50.13 |dar  0.70 |
# scGPT - INFO - | epoch  12 | 400/708 batches | lr 0.00057 | ms/batch 27.00 | loss 100.09 | gep 49.26 |gepc 50.13 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 500/708 batches | lr 0.00057 | ms/batch 31.14 | loss 100.90 | gep 49.61 |gepc 50.59 |dar  0.71 |
# scGPT - INFO - | epoch  12 | 600/708 batches | lr 0.00057 | ms/batch 26.36 | loss 101.38 | gep 49.82 |gepc 50.85 |dar  0.71 |
# scGPT - INFO - | epoch  12 | 700/708 batches | lr 0.00057 | ms/batch 25.54 | loss 101.02 | gep 49.70 |gepc 50.63 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  12 | time: 18.69s | valid loss 50.9816 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.9816
# random masking at epoch  13, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  13 | 100/708 batches | lr 0.00054 | ms/batch 26.27 | loss 102.33 | gep 50.26 |gepc 51.36 |dar  0.71 |
# scGPT - INFO - | epoch  13 | 200/708 batches | lr 0.00054 | ms/batch 28.11 | loss 99.24 | gep 48.75 |gepc 49.80 |dar  0.69 |
# scGPT - INFO - | epoch  13 | 300/708 batches | lr 0.00054 | ms/batch 31.47 | loss 100.13 | gep 49.24 |gepc 50.17 |dar  0.71 |
# scGPT - INFO - | epoch  13 | 400/708 batches | lr 0.00054 | ms/batch 26.47 | loss 99.90 | gep 49.16 |gepc 50.05 |dar  0.70 |
# scGPT - INFO - | epoch  13 | 500/708 batches | lr 0.00054 | ms/batch 26.77 | loss 99.48 | gep 48.86 |gepc 49.93 |dar  0.69 |
# scGPT - INFO - | epoch  13 | 600/708 batches | lr 0.00054 | ms/batch 28.53 | loss 99.90 | gep 49.26 |gepc 49.95 |dar  0.69 |
# scGPT - INFO - | epoch  13 | 700/708 batches | lr 0.00054 | ms/batch 19.24 | loss 100.97 | gep 49.70 |gepc 50.57 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  13 | time: 19.42s | valid loss 50.0521 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.0521
# random masking at epoch  14, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  14 | 100/708 batches | lr 0.00051 | ms/batch 32.49 | loss 101.47 | gep 49.91 |gepc 50.87 |dar  0.69 |
# scGPT - INFO - | epoch  14 | 200/708 batches | lr 0.00051 | ms/batch 26.25 | loss 98.53 | gep 48.53 |gepc 49.31 |dar  0.69 |
# scGPT - INFO - | epoch  14 | 300/708 batches | lr 0.00051 | ms/batch 26.12 | loss 100.46 | gep 49.47 |gepc 50.32 |dar  0.67 |
# scGPT - INFO - | epoch  14 | 400/708 batches | lr 0.00051 | ms/batch 24.86 | loss 98.97 | gep 48.64 |gepc 49.61 |dar  0.72 |
# scGPT - INFO - | epoch  14 | 500/708 batches | lr 0.00051 | ms/batch 27.22 | loss 99.00 | gep 48.82 |gepc 49.50 |dar  0.68 |
# scGPT - INFO - | epoch  14 | 600/708 batches | lr 0.00051 | ms/batch 28.56 | loss 100.61 | gep 49.52 |gepc 50.38 |dar  0.71 |
# scGPT - INFO - | epoch  14 | 700/708 batches | lr 0.00051 | ms/batch 29.72 | loss 98.75 | gep 48.64 |gepc 49.40 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  14 | time: 20.23s | valid loss 50.4199 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  15, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  15 | 100/708 batches | lr 0.00049 | ms/batch 27.41 | loss 100.60 | gep 49.53 |gepc 50.40 |dar  0.67 |
# scGPT - INFO - | epoch  15 | 200/708 batches | lr 0.00049 | ms/batch 27.89 | loss 97.98 | gep 48.17 |gepc 49.08 |dar  0.72 |
# scGPT - INFO - | epoch  15 | 300/708 batches | lr 0.00049 | ms/batch 27.10 | loss 99.10 | gep 48.70 |gepc 49.70 |dar  0.70 |
# scGPT - INFO - | epoch  15 | 400/708 batches | lr 0.00049 | ms/batch 19.37 | loss 98.05 | gep 48.21 |gepc 49.15 |dar  0.70 |
# scGPT - INFO - | epoch  15 | 500/708 batches | lr 0.00049 | ms/batch 31.16 | loss 99.98 | gep 49.05 |gepc 50.22 |dar  0.70 |
# scGPT - INFO - | epoch  15 | 600/708 batches | lr 0.00049 | ms/batch 27.82 | loss 99.03 | gep 48.81 |gepc 49.54 |dar  0.68 |
# scGPT - INFO - | epoch  15 | 700/708 batches | lr 0.00049 | ms/batch 27.13 | loss 98.47 | gep 48.37 |gepc 49.40 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  15 | time: 19.53s | valid loss 50.8479 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-May28-10-45
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:05<00:00, 155.68it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.776055
# ARI_cluster/label          0.905834
# ASW_label                  0.644642
# ASW_label/batch            0.854930
# PCR_batch                  0.355019
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.903129
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6446, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3550, ASW (batch): 0.8549, graph connectivity: 0.9031, graph iLISI: nan
# random masking at epoch  16, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  16 | 100/708 batches | lr 0.00046 | ms/batch 28.57 | loss 99.84 | gep 49.17 |gepc 49.99 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 200/708 batches | lr 0.00046 | ms/batch 26.81 | loss 99.72 | gep 49.11 |gepc 49.95 |dar  0.66 |
# scGPT - INFO - | epoch  16 | 300/708 batches | lr 0.00046 | ms/batch 27.04 | loss 97.27 | gep 47.79 |gepc 48.73 |dar  0.74 |
# scGPT - INFO - | epoch  16 | 400/708 batches | lr 0.00046 | ms/batch 27.12 | loss 98.06 | gep 48.21 |gepc 49.16 |dar  0.69 |
# scGPT - INFO - | epoch  16 | 500/708 batches | lr 0.00046 | ms/batch 24.83 | loss 98.01 | gep 48.21 |gepc 49.09 |dar  0.71 |
# scGPT - INFO - | epoch  16 | 600/708 batches | lr 0.00046 | ms/batch 21.54 | loss 98.69 | gep 48.58 |gepc 49.43 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 700/708 batches | lr 0.00046 | ms/batch 25.39 | loss 99.04 | gep 48.80 |gepc 49.59 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  16 | time: 18.85s | valid loss 49.2832 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 49.2832
# random masking at epoch  17, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  17 | 100/708 batches | lr 0.00044 | ms/batch 29.24 | loss 98.62 | gep 48.45 |gepc 49.47 |dar  0.70 |
# scGPT - INFO - | epoch  17 | 200/708 batches | lr 0.00044 | ms/batch 25.39 | loss 99.00 | gep 48.80 |gepc 49.55 |dar  0.64 |
# scGPT - INFO - | epoch  17 | 300/708 batches | lr 0.00044 | ms/batch 25.45 | loss 97.92 | gep 48.10 |gepc 49.11 |dar  0.71 |
# scGPT - INFO - | epoch  17 | 400/708 batches | lr 0.00044 | ms/batch 32.53 | loss 97.33 | gep 47.87 |gepc 48.76 |dar  0.70 |
# scGPT - INFO - | epoch  17 | 500/708 batches | lr 0.00044 | ms/batch 28.66 | loss 98.55 | gep 48.47 |gepc 49.43 |dar  0.65 |
# scGPT - INFO - | epoch  17 | 600/708 batches | lr 0.00044 | ms/batch 29.07 | loss 97.59 | gep 48.04 |gepc 48.85 |dar  0.70 |
# scGPT - INFO - | epoch  17 | 700/708 batches | lr 0.00044 | ms/batch 25.66 | loss 98.63 | gep 48.57 |gepc 49.39 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  17 | time: 20.42s | valid loss 48.9511 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 48.9511
# random masking at epoch  18, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  18 | 100/708 batches | lr 0.00042 | ms/batch 26.24 | loss 97.80 | gep 48.12 |gepc 49.02 |dar  0.66 |
# scGPT - INFO - | epoch  18 | 200/708 batches | lr 0.00042 | ms/batch 28.14 | loss 97.05 | gep 47.65 |gepc 48.71 |dar  0.70 |
# scGPT - INFO - | epoch  18 | 300/708 batches | lr 0.00042 | ms/batch 22.45 | loss 98.34 | gep 48.37 |gepc 49.27 |dar  0.70 |
# scGPT - INFO - | epoch  18 | 400/708 batches | lr 0.00042 | ms/batch 27.76 | loss 97.28 | gep 47.95 |gepc 48.68 |dar  0.65 |
# scGPT - INFO - | epoch  18 | 500/708 batches | lr 0.00042 | ms/batch 26.18 | loss 97.67 | gep 48.06 |gepc 48.90 |dar  0.72 |
# scGPT - INFO - | epoch  18 | 600/708 batches | lr 0.00042 | ms/batch 25.20 | loss 96.22 | gep 47.34 |gepc 48.17 |dar  0.71 |
# scGPT - INFO - | epoch  18 | 700/708 batches | lr 0.00042 | ms/batch 28.33 | loss 97.25 | gep 47.89 |gepc 48.71 |dar  0.64 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  18 | time: 19.13s | valid loss 50.2256 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  19, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  19 | 100/708 batches | lr 0.00040 | ms/batch 32.88 | loss 98.38 | gep 48.28 |gepc 49.40 |dar  0.70 |
# scGPT - INFO - | epoch  19 | 200/708 batches | lr 0.00040 | ms/batch 24.89 | loss 96.50 | gep 47.54 |gepc 48.28 |dar  0.67 |
# scGPT - INFO - | epoch  19 | 300/708 batches | lr 0.00040 | ms/batch 26.14 | loss 98.11 | gep 48.26 |gepc 49.17 |dar  0.68 |
# scGPT - INFO - | epoch  19 | 400/708 batches | lr 0.00040 | ms/batch 25.71 | loss 96.09 | gep 47.27 |gepc 48.14 |dar  0.67 |
# scGPT - INFO - | epoch  19 | 500/708 batches | lr 0.00040 | ms/batch 27.11 | loss 97.45 | gep 47.82 |gepc 48.90 |dar  0.74 |
# scGPT - INFO - | epoch  19 | 600/708 batches | lr 0.00040 | ms/batch 30.16 | loss 96.60 | gep 47.50 |gepc 48.45 |dar  0.64 |
# scGPT - INFO - | epoch  19 | 700/708 batches | lr 0.00040 | ms/batch 28.75 | loss 97.86 | gep 48.13 |gepc 49.09 |dar  0.64 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  19 | time: 20.27s | valid loss 49.9195 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  20, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  20 | 100/708 batches | lr 0.00038 | ms/batch 18.14 | loss 98.35 | gep 48.34 |gepc 49.33 |dar  0.67 |
# scGPT - INFO - | epoch  20 | 200/708 batches | lr 0.00038 | ms/batch 27.45 | loss 96.14 | gep 47.20 |gepc 48.24 |dar  0.70 |
# scGPT - INFO - | epoch  20 | 300/708 batches | lr 0.00038 | ms/batch 26.51 | loss 97.49 | gep 47.93 |gepc 48.85 |dar  0.70 |
# scGPT - INFO - | epoch  20 | 400/708 batches | lr 0.00038 | ms/batch 24.66 | loss 97.51 | gep 48.04 |gepc 48.81 |dar  0.65 |
# scGPT - INFO - | epoch  20 | 500/708 batches | lr 0.00038 | ms/batch 30.13 | loss 96.32 | gep 47.29 |gepc 48.32 |dar  0.72 |
# scGPT - INFO - | epoch  20 | 600/708 batches | lr 0.00038 | ms/batch 29.93 | loss 97.13 | gep 47.79 |gepc 48.64 |dar  0.69 |
# scGPT - INFO - | epoch  20 | 700/708 batches | lr 0.00038 | ms/batch 25.32 | loss 96.37 | gep 47.44 |gepc 48.26 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  20 | time: 19.05s | valid loss 48.6561 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 48.6561
# scGPT - INFO - Saving model to save/dev_BMMC-May28-10-45
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:04<00:00, 166.35it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.723808
# ARI_cluster/label          0.821371
# ASW_label                  0.642818
# ASW_label/batch            0.873273
# PCR_batch                  0.373349
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.921199
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6428, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3733, ASW (batch): 0.8733, graph connectivity: 0.9212, graph iLISI: nan
# random masking at epoch  21, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  21 | 100/708 batches | lr 0.00036 | ms/batch 26.28 | loss 96.25 | gep 47.19 |gepc 48.27 |dar  0.79 |
# scGPT - INFO - | epoch  21 | 200/708 batches | lr 0.00036 | ms/batch 27.20 | loss 95.92 | gep 47.11 |gepc 48.14 |dar  0.67 |
# scGPT - INFO - | epoch  21 | 300/708 batches | lr 0.00036 | ms/batch 18.41 | loss 96.02 | gep 47.16 |gepc 48.17 |dar  0.69 |
# scGPT - INFO - | epoch  21 | 400/708 batches | lr 0.00036 | ms/batch 24.93 | loss 95.79 | gep 47.11 |gepc 48.00 |dar  0.67 |
# scGPT - INFO - | epoch  21 | 500/708 batches | lr 0.00036 | ms/batch 30.13 | loss 97.15 | gep 47.73 |gepc 48.73 |dar  0.68 |
# scGPT - INFO - | epoch  21 | 600/708 batches | lr 0.00036 | ms/batch 26.80 | loss 95.64 | gep 47.01 |gepc 47.93 |dar  0.70 |
# scGPT - INFO - | epoch  21 | 700/708 batches | lr 0.00036 | ms/batch 26.63 | loss 96.94 | gep 47.67 |gepc 48.57 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  21 | time: 18.72s | valid loss 49.8199 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  22, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  22 | 100/708 batches | lr 0.00034 | ms/batch 24.15 | loss 96.47 | gep 47.45 |gepc 48.31 |dar  0.71 |
# scGPT - INFO - | epoch  22 | 200/708 batches | lr 0.00034 | ms/batch 24.67 | loss 96.15 | gep 47.27 |gepc 48.21 |dar  0.68 |
# scGPT - INFO - | epoch  22 | 300/708 batches | lr 0.00034 | ms/batch 25.53 | loss 94.79 | gep 46.60 |gepc 47.49 |dar  0.70 |
# scGPT - INFO - | epoch  22 | 400/708 batches | lr 0.00034 | ms/batch 32.38 | loss 95.79 | gep 47.12 |gepc 47.99 |dar  0.68 |
# scGPT - INFO - | epoch  22 | 500/708 batches | lr 0.00034 | ms/batch 27.75 | loss 95.83 | gep 47.11 |gepc 48.02 |dar  0.70 |
# scGPT - INFO - | epoch  22 | 600/708 batches | lr 0.00034 | ms/batch 25.09 | loss 95.66 | gep 46.97 |gepc 47.99 |dar  0.70 |
# scGPT - INFO - | epoch  22 | 700/708 batches | lr 0.00034 | ms/batch 24.37 | loss 97.21 | gep 47.79 |gepc 48.72 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  22 | time: 18.41s | valid loss 49.6644 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  23, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  23 | 100/708 batches | lr 0.00032 | ms/batch 27.03 | loss 96.83 | gep 47.57 |gepc 48.53 |dar  0.72 |
# scGPT - INFO - | epoch  23 | 200/708 batches | lr 0.00032 | ms/batch 28.23 | loss 95.34 | gep 46.86 |gepc 47.78 |dar  0.71 |
# scGPT - INFO - | epoch  23 | 300/708 batches | lr 0.00032 | ms/batch 25.94 | loss 94.11 | gep 46.23 |gepc 47.18 |dar  0.70 |
# scGPT - INFO - | epoch  23 | 400/708 batches | lr 0.00032 | ms/batch 25.88 | loss 96.40 | gep 47.38 |gepc 48.32 |dar  0.69 |
# scGPT - INFO - | epoch  23 | 500/708 batches | lr 0.00032 | ms/batch 26.39 | loss 95.74 | gep 47.04 |gepc 48.02 |dar  0.68 |
# scGPT - INFO - | epoch  23 | 600/708 batches | lr 0.00032 | ms/batch 26.76 | loss 94.91 | gep 46.64 |gepc 47.56 |dar  0.71 |
# scGPT - INFO - | epoch  23 | 700/708 batches | lr 0.00032 | ms/batch 29.21 | loss 97.08 | gep 47.64 |gepc 48.74 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  23 | time: 19.66s | valid loss 47.9975 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 47.9975
# random masking at epoch  24, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  24 | 100/708 batches | lr 0.00031 | ms/batch 31.23 | loss 96.13 | gep 47.25 |gepc 48.21 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 200/708 batches | lr 0.00031 | ms/batch 24.18 | loss 95.70 | gep 47.02 |gepc 48.00 |dar  0.68 |
# scGPT - INFO - | epoch  24 | 300/708 batches | lr 0.00031 | ms/batch 25.67 | loss 96.53 | gep 47.48 |gepc 48.32 |dar  0.73 |
# scGPT - INFO - | epoch  24 | 400/708 batches | lr 0.00031 | ms/batch 26.34 | loss 94.74 | gep 46.58 |gepc 47.50 |dar  0.66 |
# scGPT - INFO - | epoch  24 | 500/708 batches | lr 0.00031 | ms/batch 20.04 | loss 95.03 | gep 46.67 |gepc 47.67 |dar  0.69 |
# scGPT - INFO - | epoch  24 | 600/708 batches | lr 0.00031 | ms/batch 30.79 | loss 94.59 | gep 46.41 |gepc 47.48 |dar  0.70 |
# scGPT - INFO - | epoch  24 | 700/708 batches | lr 0.00031 | ms/batch 26.05 | loss 95.44 | gep 46.96 |gepc 47.80 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  24 | time: 19.17s | valid loss 48.1143 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  25, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  25 | 100/708 batches | lr 0.00029 | ms/batch 25.26 | loss 95.92 | gep 47.06 |gepc 48.17 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 200/708 batches | lr 0.00029 | ms/batch 27.16 | loss 94.02 | gep 46.15 |gepc 47.17 |dar  0.71 |
# scGPT - INFO - | epoch  25 | 300/708 batches | lr 0.00029 | ms/batch 25.34 | loss 95.41 | gep 46.90 |gepc 47.84 |dar  0.67 |
# scGPT - INFO - | epoch  25 | 400/708 batches | lr 0.00029 | ms/batch 25.27 | loss 94.45 | gep 46.40 |gepc 47.35 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 500/708 batches | lr 0.00029 | ms/batch 28.02 | loss 95.41 | gep 46.89 |gepc 47.85 |dar  0.68 |
# scGPT - INFO - | epoch  25 | 600/708 batches | lr 0.00029 | ms/batch 24.10 | loss 95.09 | gep 46.68 |gepc 47.73 |dar  0.68 |
# scGPT - INFO - | epoch  25 | 700/708 batches | lr 0.00029 | ms/batch 27.17 | loss 95.62 | gep 46.97 |gepc 47.96 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  25 | time: 19.00s | valid loss 48.1209 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-May28-10-45
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:04<00:00, 170.94it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.767519
# ARI_cluster/label          0.899231
# ASW_label                  0.644535
# ASW_label/batch            0.868885
# PCR_batch                  0.405559
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.926417
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6445, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4056, ASW (batch): 0.8689, graph connectivity: 0.9264, graph iLISI: nan

# %%
# save the best model
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
artifact = wandb.Artifact(f"best_model", type="model")
glob_str = os.path.join(save_dir, "best_model.pt")
artifact.add_file(glob_str)
run.log_artifact(artifact)

run.finish()
wandb.finish()
gc.collect()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>▁█▇▃▆</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>test/ARI_cluster/label</td><td>▁█▇▄▆</td></tr><tr><td>test/ASW_label</td><td>█▁▁▁▁</td></tr><tr><td>test/ASW_label/batch</td><td>▁▃▆██</td></tr><tr><td>test/NMI_cluster/label</td><td>▁█▇▃▆</td></tr><tr><td>test/PCR_batch</td><td>▁▇▅▆█</td></tr><tr><td>test/avg_bio</td><td>▁█▇▃▆</td></tr><tr><td>test/best_model_epoch</td><td>▁▃▄▇█</td></tr><tr><td>test/graph_conn</td><td>▁▆▆▇█</td></tr><tr><td>train/dab</td><td>█▇█▅▅▄▂▅▇▄▅▆▄▅▃▄▇▅▅▃▄▆▃▃▆▂▃▄▇▁▅▆▄▂▂█▅▆▆▇</td></tr><tr><td>train/gep</td><td>█▂▂▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/mvc</td><td>█▆▅▄▃▂▂▂▂▂▂▂▂▂▃▃▃▂▁▂▂▂▂▂▁▂▂▂▂▂▂▁▂▂▁▂▂▂▂▁</td></tr><tr><td>valid/loss</td><td>█▅▄▃▃▃▃▄▂▂▃▂▂▂▂▂▁▂▂▁▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>0.77043</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>test/ARI_cluster/label</td><td>0.89923</td></tr><tr><td>test/ASW_label</td><td>0.64454</td></tr><tr><td>test/ASW_label/batch</td><td>0.86888</td></tr><tr><td>test/NMI_cluster/label</td><td>0.76752</td></tr><tr><td>test/PCR_batch</td><td>0.40556</td></tr><tr><td>test/best_model_epoch</td><td>23</td></tr><tr><td>test/graph_conn</td><td>0.92642</td></tr><tr><td>train/dab</td><td>0.62369</td></tr><tr><td>train/gep</td><td>45.16808</td></tr><tr><td>train/mvc</td><td>45.42764</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">toasty-spaceship-11</strong> at: <a href='https://wandb.ai/apex_1465/scGPT/runs/xjgb760m' target="_blank">https://wandb.ai/apex_1465/scGPT/runs/xjgb760m</a><br> View project at: <a href='https://wandb.ai/apex_1465/scGPT' target="_blank">https://wandb.ai/apex_1465/scGPT</a><br>Synced 5 W&B file(s), 10 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250528_104518-xjgb760m/logs</code>
# 87775
